# %% [markdown]
# # Partie C - Exercices
# ## C.1 Listes
# ## Exercice 1 - Indices
# Remplace les *???* dans la liste pour obtenir les bonnes réponses.

# %%
liste = [5,7,2,6,1,3,4,9,8]
# trouve les bons indices
nb_aux_indices_5_à_7_inclus = liste[ ??? : ???]
# dans la liste remplace le nombre 1 par 0 : trouve le bon indice
liste[ ??? ] = 0

# NE PAS MODIFIER LE CODE CI-DESSOUS 
assert nb_aux_indices_5_à_7_inclus == [3,4,9]
assert liste == [5,7,2,6,0,3,4,9,8]
print("OK!")

# %% [markdown]
# ## Exercice 2 - C'est mon choix
# Crée une liste nommée *ma_liste* avec 3 éléments de ton choix dedans

# %%
# NE PAS MODIFIER LE CODE CI-DESSOUS 
assert'ma_liste' in globals() and len(ma_liste) == 3  
print("OK!")

# %% [markdown]
# ## Exercice 3 - J'aime pas
# Complète le code pour remplacer ce que tu n'aimes pas dans la liste "iLove" par quelque chose que tu aimes.\
# (Si tu aimes tout dans la liste il faudra quand même remplacer quelque chose :p )

# %%
iLove = ["les chats", "la mer", "la programmation", "les brocolis", "System of a Down"]
indiceDeLaChoseCouranteDansLaListe = 0
indiceDeCeQueJeNAimePas = -1
# pour chaque chose que j'aime dans la liste iLove... 
for ??? in ??? :
    # affiche la chose courante 
    print(iLove[???])
    # si la chose est égale à ce que je n'aime pas 
    if ??? == ??? :  
        # alors on récupère son indice pour pouvoir le modifier
       ??? = indiceDeLaChoseCouranteDansLaListe 
    # on ajoute 1 à indiceDeLaChoseCouranteDansLaListe
    indiceDeLaChoseCouranteDansLaListe = indiceDeLaChoseCouranteDansLaListe + 1
# on modifie l'objet qui est à l'indice ???
iLove[???] = "une chose que j'aime"       
print("j'aime :", iLove)

# %% [markdown]
# ## Exercice 4 - Vous (ne) passerez (pas) !
# Complète le code pour calculer la moyenne de l'élève.\
# (ne pas ternir compte des histoires de panier et autre, juste faire une moyenne!)

# %%
bulletin = [4, 4, 3, 5]
# initialiser la somme

# pour chaque note dans le bulletin

    # ajoute la note à la somme de points
    
# calcule et affiche la moyenne (somme des points/nombre de notes)

# %% [markdown]
# ## Exercice 5 (difficile - optionnel) - Le coissou
# Recherche et affiche l'indice de l'élément ayant la plus petite valeur
# - tu auras besoin d'un *for*, d'un *if* et deux variables supplémentaires !

# %%
liste = [5,7,2,6,1,3,4,9,8]
#...


# for pour parcourir la lise 

    # si la valeur courante est plus petite que la valeur minimale actuelle... 
   
        # ...

    # compteur + 1

# afficher la valeur minimum ET sa position/son indice dans la liste

# %% [markdown]
# ## C.2 Dictionnaires
# ## Exercice 6 - Sing
# En utilisant une fois chaque fonction (append/insert), ajoute les chanteurs suivants dans la liste en respectant l'ordre alphabétique :
# - "Mika"
# - "Adèle"
# - "The Edge"

# %%
singers = ["Elton", "John", "Michael"]


# NE PAS MODIFIER LE CODE CI-DESSOUS 
assert singers == ["Adèle", "Elton", "John", "Michael", "Mika", "The Edge"]
print("OK!")

# %% [markdown]
# ## Exercice 7- Pop Music
# En utilisant une fois chaque fonction (remove/pop), supprime les chanteurs décédés (John et Michael) dans la liste... :-(

# %%
alivesingers = ["Elton", "John", "Michael"]


# NE PAS MODIFIER LE CODE CI-DESSOUS 
assert alivesingers == ["Elton"]
print("OK!")

# %% [markdown]
# ## Exercice 8 - Dico d'or
# Change le prénom de l'élève pour "Neymar" et le nom pour "Da Silva", et enlève la clé "numéro" et ajoue la clé "club" ayant comme valeur "sans".

# %%
joueur = {"nom":"Neymar","prenom":"Jean","numero":"10"}




# NE PAS MODIFIER LE CODE CI-DESSOUS 
assert joueur ""= {"nom":"Da Silva","prenom":"Neymar","club":"sans"}
print("OK!")

# %% [markdown]
# ## Exercice 9 - LM > CR7
# PARCOURS LA LISTE pour trouver Lionel Messi et affiche le nombre de ballon d'or obtenus !

# %%
ballonsdor = [
    {"prenom":"Cristiano","nom":"Ronaldo","nombres":"5"}, 
    {"prenom":"Michel","nom":"Platini","nombres":"3"}, 
    {"prenom":"Lionel","nom":"Messi","nombres":"8"}, 
    {"prenom":"Johan","nom":"Cruyff","nombres":"3"}, 
    {"prenom":"Marco","nom":"van Basten","nombres":"3"}, 
    {"prenom":"Franz","nom":"Beckenbauer","nombres":"3"}
]

# %% [markdown]
# ## C.3 Fonctions
# ## Exercice 10 - I saw the sign
# Modifie le code suivant pour qu'il soit juste !
# - exécute le pour voir ce qui cloche
# - teste avec avec 2,-2 et 0 pour voir si il est juste

# %%
def quel_signe(x):
    if x == 0:
        return 'positif'
    elif x > 0:
        return 'négatif'
    else:
        return 'nul'

le_nombre = int(input('Entrez un nombre: '))
print(le_nombre, 'est', quel_signe(le_nombre))

# %% [markdown]
# ## Exercice 11 - Seconds
# Remplace les *???* pour que le code transforme les minutes de l'heure actuelle en secondes

# %%
from datetime import datetime

def transforme_en_secondes(???):
        return ??? * 60
    
minutes = datetime.now().minute    
résultat = transforme_en_secondes(???)
print(résultat)

# %% [markdown]
# ## Exercice 12 - chien et chat
# Remplace les *???* pour créer une fonction nommée *quel_bruit()*, qui aura comme argument la variable *animal* qui renvoie le bon résultat.\
# PAS BESOIN DE modifier autre chose que les *???*

# %%
def ???(???) :
    if ??? == "chat"
        ??? "miaou"
    else :
        ??? "wouf"

animal = "chat"
bruit = quel_bruit(animal)
print("le ",animal,"fait", bruit)

animal = "chien"
bruit = quel_bruit(animal)
print("le ",animal,"fait", bruit)

# %% [markdown]
# ## Exercice 13 (difficile--) - The Village
# Un village en zone périurbaine compte aujourd'hui 2300 habitants.\
# Le village voit sa population augmenter chaque année de 120 habitants.\
# Ecrit une fonction nommée *population(n)* et qui renvoie la population de ce village au bout de *n* années.

# %%
# NE PAS MODIFIER LE CODE CI-DESSOUS 
assert population(10) == 3500  
print("OK!")

# %% [markdown]
# ## C.4 Import
# ## Exercice 14 (difficile) - Alea Jacta Est
# Écris le programme suivant
# - la fonction lancer_le_dé(max), ou l’argument « max » est la valeur max du dé (il y a des dés 6 mais aussi 20, 100…) et qui retourne le résultat du lancer
# - il faudra bien évidemment importer le module « random » et utiliser la fonction *randint()*
# - avec une boucle, appeler 1000 la fonction et stocker le résultat dans une liste
# - calculer et afficher le résultat moyen
# Bonus : affiche la dispersion des lancés dans un graphique de type nuage de point en utilisant le module matplotlib
