# %% [markdown]
# # Partie A - Exercices

# %% [markdown]
# ## A.1 VARIABLES
# ## Exercice 1 - Creér une variable
# LIGNE 1 : crée une variable nommée "titi", et met la valeur "5" dedans, puis exécute le code avec le "bouton" play.
# Attention !
# 1) respecter la casse sur le nom de la variable
# 2) bien évidemment, ne pas mettre les guillemets
# 3) ne pas supprimer lles autres lignes

# %%
# ne pas modifier à partir d'ici
if 'titi' in globals() and titi == 5 : 
    print("Exercice OK ! Vous avez créé votre 1ère variable !")
else :
    print("vous n'avez pas suivi les consignes :( ")

# %% [markdown]
# ## Exercice 2 - Creér des variables
# 1) ligne 1 : crée une variable nommée *nb1* et affecte lui (met dedans) la valeur 1
# 2) ligne 2 : crée une variable nommée *nb2* et affecte lui la valeur 3
# 3) ligne 3 : crée une variable nommée *total* et affecte lui le résulat de l'addition nb1 + nb2

# %%
# ne pas modifier à partir d'ici
if all(x in globals() for x in ('nb1', 'nb2', 'total') ) and total == 4 :     
    print("Exercice OK !")
else :
    print("vous n'avez pas suivi les consignes :( ")

# %% [markdown]
# ## A.2 TYPES ET NOMMAGE
# ## Exercice 3 - Les types
# Pour les 4 variables, remplace les "??" par une valeur du bon type :

# %%
var_str = ??
var_bool = ??
var_int = ??
var_float = ??

# ne pas modifier à partir d'ici
assert type(var_str) == str
assert type(var_bool) == bool
assert type(var_int) == int
assert type(var_float) == float
print("exo OK!")

# %% [markdown]
# ## Exercice 4 - Nommage
# Corrige les noms des variables pour ne plus avoir d'erreurs :

# %%
9Chiffre = 123456789
J'aime les brocoli = False
# ne pas modifier à partir d'ici
print("exo OK!")

# %% [markdown]
# ## Exercice 5 - Correction de code
# Corrige les erreurs dans le code suivant :

# %%
7 = nb_1
nb_2 = 8
nb_3 = "9"
nb_4 == 6
le_résultat = nb_1 + nb2 + nb_3 + nb_4
pint(le_résultat)
# ne pas modifier à partir d'ici
assert le_résultat == 30
print("exo ok!")

# %% [markdown]
# ## A.3 PRINT ET INPUT
# ## Exercice 6 - print() et input()
# Remplace les "??" par print() ou input()

# %%
??("Bonjour !")
age = int(??("Quel age as-tu ?"))
??("wouh, tu as", age ,"ans!")

# %% [markdown]
# ## Exercice 7 - Afficher Demander Afficher
# Imagine une conversation où :
# 1) tu affiches "salut"
# 2) tu demandes le prénom et tu le mets dans une variable
# 3) tu affiches "enchanté XXX"

# %% [markdown]
# ## A.4 OPÉRATEURS
# ## Exercice 8 - Opérateurs
#
# Remplace "??" par le calcul suivant :
# $(45 + 25) (2 + 3) / 2 + (3^2)$

# %%
resultat = ??

# ne pas modifier à partir d'ici
assert resultat == 184, "Erreur dans le calcul"
print("Nickel !")

# %% [markdown]
# ## Exercice 9 - Strings
# Ligne 4, affiche le texte suivant en utilisant les variables a, b et c :\
# Welcome home losers !
#
# (c'est une référence à Futurama S01E08 ainsi qu'au film Armageddon)

# %%
a = "home "
b = "Welcome "
c = "losers !"

# %% [markdown]
# ## Exercice 10 - l'Or
#
# 1. Enregistre dans une variable prix d’un kilogramme d’or, à savoir 96 000 Fr.
# 2. Enregistre dans une variable le nombre de kilogrammes d'or commandé, à savoir 12.441 Kg.
# 3. Calcule le prix de cette commande et enregistre le résultat dans une variable.
# 4. Affiche le résultat
#
# (12,441 kg est le poids des lingots stockés dans les coffres des banques centrales)

# %%
# bien lire l'énoncé !

# %% [markdown]
# ## Exercice 11 - Vrai ou Faux ?
# Remplace les "??" par des opérateurs de comparaison pour que le résultat des assertions soit toujours vrai :
# https://fr.wikipedia.org/wiki/Assertion

# %%
assert 12 ?? 12
assert 6 ?? 100
assert -14 ?? -15
assert True ?? True
assert True ?? False
assert "chat" ?? "chien"
assert "chat" ?? "chat"
print("Exercice OK!")

# %% [markdown]
# ## Exercice 12 - le OR
# Fait en sorte que toute les assertions soient vraies :
# - Remplace les "??" par 1 ou 0 (c'est l'équivalent de TRUE OU FALSE : c.f. le 1er chapitre d'info.!)
# - Remplace les "???" par un opérateur logique *or* ou *and*

# %%
assert (1 ??? 0) == 0
assert (1 ??? 0) == 1
assert (?? and ??) == 1
assert (0 or 0) == ??

# %% [markdown]
# ## A.5 IF ELSE
# ## Exercice 13 - VRAI ET VRAI
# Pour que la réponse à la question "Je_peux_boire_uniquement_des_alcools_fermentés" soit vraie :
# - Remplace les "??" par des opérateurs de comparaison
# - Remplace le "???" par un opérateur logique
# - Ne pas modifier le reste du code !
#
# (alcools fermentés : vin ou bière ou cidre. À 18 ans vous pouvez boire plus! (avec modération - avant 25 ans l'alcool peut avoir un impact très négatif sur le cerveau...)))

# %%
age = 15
Je_peux_boire_uniquement_des_alcools_fermentés = ""

while age ?? 19 :
    if age ?? 16 ??? age ?? 18 : 
        Je_peux_boire_uniquement_des_alcools_fermentés += str(age)        
        print("j'ai",age,"ans et je peux boire uniquement des alcools fermentés")
    age += 1

assert Je_peux_boire_uniquement_des_alcools_fermentés == "1617"
print("Exercice OK!")

# %% [markdown]
# ## Exercice 14 - Indentation
#
# Corrige le code suivant pour lui donner la bonne indentation :

# %%
    print("bonjour !")
poids = 2 
    if poids > 20 : 
print("tu peux aller à Europapark")
else :
    print("va falloir grossir")
    print("Au revoir !")

# %% [markdown]
# ## Exercice 15 - If Else
# Complète le code suivant pour qu'il soit correct.\
# N'oublie pas de donner un nombre quand tu exécutes le programme et que l'ordinateur le demande ! 🤖
# - Remplace les "???" par *if* ou *else*

# %%
nb = int(input("donne moi un nombre"))
??? nb % 2 == 0 : 
    print("il est pair")
??? : 
    print("il est impair")
??? nb // 1 == nb   : 
    print("c'est un réel")
??? nb < 0 :
        print("c'est un entier relatif")
print("c'est un entier")

# %% [markdown]
# ## Exercice 16 - On enlève les roulettes !
# Ecrit un programme qui demande un mot de passe à l’utilisateur :
# - si le mot de passe est correct, affiche "Mot de passe correct !"
# - si il est incorrect, affichez "Mot de passe incorrect"
#
# Il devrait y avoir UNE ligne de code par ligne vide 😄

# %%
# Créer une variable contenant le BON mot de passe

# DEMANDER le mot de passe et le STOCKER dans une variable 

# SI le mot de passe proposé est EGAL au bon mot de passe...

# ... alors AFFICHER le message "OK"

# ...SINON... 

# ...AFFICHER "KO"
